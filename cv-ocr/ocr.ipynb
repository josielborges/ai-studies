# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('esporte.png')

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

_, img_thresh = cv2.threshold(img_gray, 150, 255, cv2.THRESH_BINARY)



plt.imshow(img_gray, cmap='gray')
plt.axis('off')
# plt.show()

text = pytesseract.image_to_string(img_gray, lang='por')
print(f'text -> {text}')
# Out:
# text ->

# %%
img
# Out:
# array([[[185, 127,   0],
#         [185, 128,   0],
#         [183, 126,   0],
#         ...,
#         [172, 119,   0],
#         [172, 122,   0],
#         [168, 121,   0]],
#
#        [[184, 127,   0],
#         [184, 128,   0],
#         [183, 126,   0],
#         ...,
#         [172, 120,   0],
#         [172, 122,   0],
#         [170, 120,   0]],
#
#        [[184, 127,   0],
#         [184, 127,   0],
#         [184, 127,   0],
#         ...,
#         [172, 121,   0],
#         [172, 122,   0],
#         [171, 122,   0]],
#
#        ...,
#
#        [[180, 167, 152],
#         [180, 167, 152],
#         [182, 169, 150],
#         ...,
#         [139, 151, 194],
#         [139, 150, 195],
#         [138, 149, 194]],
#
#        [[182, 169, 153],
#         [182, 169, 153],
#         [181, 169, 155],
#         ...,
#         [138, 150, 194],
#         [137, 150, 192],
#         [135, 149, 191]],
#
#        [[181, 169, 155],
#         [181, 169, 155],
#         [183, 169, 155],
#         ...,
#         [136, 149, 189],
#         [134, 148, 185],
#         [135, 148, 186]]], dtype=uint8)

# %%
img_gray
# Out:
# array([[ 96,  96,  95, ...,  89,  91,  90],
#        [ 96,  96,  95, ...,  90,  91,  90],
#        [ 96,  96,  96, ...,  91,  91,  91],
#        ...,
#        [164, 164, 165, ..., 162, 162, 161],
#        [166, 166, 166, ..., 162, 161, 160],
#        [166, 166, 166, ..., 159, 157, 158]], dtype=uint8)
